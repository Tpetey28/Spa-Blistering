# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('model_dataset.xlsx')
df = df.dropna()

# %%
df[['shell_color','model', 'time_description']] = df[['shell_color','model', 'time_description']].apply(lambda x: pd.factorize(x)[0])
df['hour'] = df['end_time'].dt.hour
df.drop(['start_time','end_time','t_stamp','stamp_date'],inplace=True, axis=1)

# %%
df.head(1)
# Out:
#    serial#  blister  shell_color  model  time_description  iso_press_avg  \
# 0   281689        0            0      0                 0      19.999573
#
#    poly_press_avg  booth  iso_lbs_run_usage  poly_lbs_run_usage  spray_time  \
# 0             1.0      4            46966.3             70449.4    0.908153
#
#    Avg Temp  Avg Dew Point  Avg Humidity  Avg Pressure  Total Precipitation  \
# 0      38.7           22.3          55.0          26.0                  0.0
#
#    hour
# 0    21

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Pearson Correlation
# Filtering Method 1

# %%
X = df.loc[:, df.columns!='blister']
y = df['blister']

# %%
X.shape
# Out:
# (54221, 16)

# %%
num_feats = 10

# %%
def cor_selector(X, y,num_feats):
    cor_list = []
    feature_name = X.columns.tolist()
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-num_feats:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature
cor_support, cor_feature = cor_selector(X,y,num_feats)
print(str(len(cor_feature)), 'selected features')
print(cor_feature)
# Out:
# 10 selected features
# ['Avg Dew Point', 'booth', 'time_description', 'iso_press_avg', 'poly_press_avg', 'model', 'shell_color', 'iso_lbs_run_usage', 'serial#', 'poly_lbs_run_usage']

# %% [markdown]
# ## Chi Squared
# Filtering Method 2

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=num_feats)
chi_selector.fit(X_norm, y)
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()
print(str(len(chi_feature)), 'selected features')
print(chi_feature)
# Out:
# 10 selected features
# ['serial#', 'shell_color', 'model', 'time_description', 'iso_press_avg', 'poly_press_avg', 'booth', 'iso_lbs_run_usage', 'poly_lbs_run_usage', 'Avg Temp']

# %% [markdown]
# ## Recursive Feature Elimination
# Wrapper Method 1

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=num_feats, step=10, verbose=5)
rfe_selector.fit(X_norm, y)
rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
print(rfe_feature)
# Out:
# Fitting estimator with 16 features.
# 10 selected features
# ['serial#', 'shell_color', 'model', 'time_description', 'iso_press_avg', 'poly_press_avg', 'iso_lbs_run_usage', 'poly_lbs_run_usage', 'Avg Temp', 'Avg Humidity']

# %% [markdown]
# ## Lasso: SelectFromModel
#
# Embedded Method 1

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l2"), max_features=num_feats)
embeded_lr_selector.fit(X_norm, y)

embeded_lr_support = embeded_lr_selector.get_support()
embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
print(str(len(embeded_lr_feature)), 'selected features')
print(embeded_lr_feature)
# Out:
# 6 selected features
# ['serial#', 'shell_color', 'model', 'iso_press_avg', 'poly_press_avg', 'poly_lbs_run_usage']

# %% [markdown]
# ## Tree-based: SelectFromModel
#
# Embedded Method 2

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), max_features=num_feats)
embeded_rf_selector.fit(X, y)

embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
print(embeded_rf_feature)
# Out:
# 6 selected features
# ['serial#', 'iso_press_avg', 'poly_press_avg', 'iso_lbs_run_usage', 'poly_lbs_run_usage', 'spray_time']

# %% [markdown]
# ## LightGBM: SelectFromModel
#
# Embedded Method 3

# %%
from sklearn.feature_selection import SelectFromModel
from lightgbm import LGBMClassifier

lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
            reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

embeded_lgb_selector = SelectFromModel(lgbc, max_features=num_feats)
embeded_lgb_selector.fit(X, y)

embeded_lgb_support = embeded_lgb_selector.get_support()
embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
print(str(len(embeded_lgb_feature)), 'selected features')
print(embeded_lgb_feature)
# Out:
# 10 selected features
# ['serial#', 'model', 'iso_press_avg', 'poly_press_avg', 'iso_lbs_run_usage', 'poly_lbs_run_usage', 'spray_time', 'Avg Temp', 'Avg Dew Point', 'Avg Humidity']

# %% [markdown]
# # Narrowing Selection
#
# Based on the above feature selection methods, below are the features that we will be using to narrow down our search.
#
# 1. Model
# 2. iso_press_avg
# 3. poly_press_avg
# 4. iso_lbs_run_usage
# 5. poly_lbs_run_usage
# 6. shell_color
# 7. Avg Temp
# 8. Avg Humidity
# 9. Time Description
# 10. Booth

# %%
X = df[['blister','model','shell_color','time_description','iso_press_avg','poly_press_avg','booth','iso_lbs_run_usage','poly_lbs_run_usage','Avg Temp','Avg Humidity']]

# %% [markdown]
# ## Evaluating Collinearity
#
# Based on correlation matrix and VIF scores below, here are the features we will keep:
# 1. Model
# 2. Shell_Color
# 3. poly_press_avg
# 4. avg_temp
# 5. poly_lbs_run_usage
# 6. time_description
# 7. booth

# %%
#plot color scaled correlation matrix
corr=X.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_249d9_row0_col0, #T_249d9_row1_col1, #T_249d9_row2_col2, #T_249d9_row3_col3, #T_249d9_row4_col4, #T_249d9_row5_col5, #T_249d9_row6_col6, #T_249d9_row7_col7, #T_249d9_row7_col8, #T_249d9_row8_col7, #T_249d9_row8_col8, #T_249d9_row9_col9, #T_249d9_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_249d9_row0_col1, #T_249d9_row4_col6, #T_249d9_row10_col5 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_249d9_row0_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_249d9_row0_col3, #T_249d9_row2_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_249d9_row0_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_249d9_row0_col5, #T_249d9_row3_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_249d9_row0_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_249d9_row0_col7 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_249d9_row0_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_249d9_row0_col9, #T_249d9_row0_col10 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_249d9_row1_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_249d9_row1_col2, #T_249d9_row4_col8 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_249d9_row1_col3, #T_249d9_row2_col1, #T_249d9_row2_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_249d9_row1_col4, #T_249d9_row3_col7, #T_249d9_row3_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_249d9_row1_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_249d9_row1_col6, #T_249d9_row5_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_249d9_row1_col7, #T_249d9_row1_col8 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_249d9_row1_col9, #T_249d9_row1_col10, #T_249d9_row2_col10 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_249d9_row2_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_249d9_row2_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_249d9_row2_col6, #T_249d9_row3_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_249d9_row2_col7, #T_249d9_row2_col8 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_249d9_row2_col9 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_249d9_row3_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_249d9_row3_col1, #T_249d9_row5_col8, #T_249d9_row6_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_249d9_row3_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_249d9_row3_col6, #T_249d9_row4_col1, #T_249d9_row5_col0, #T_249d9_row5_col1, #T_249d9_row6_col2, #T_249d9_row7_col1, #T_249d9_row7_col3, #T_249d9_row8_col1, #T_249d9_row8_col3, #T_249d9_row8_col5, #T_249d9_row9_col2, #T_249d9_row9_col7, #T_249d9_row9_col8, #T_249d9_row9_col10, #T_249d9_row10_col1, #T_249d9_row10_col4, #T_249d9_row10_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_249d9_row3_col9 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_249d9_row3_col10 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_249d9_row4_col0, #T_249d9_row4_col2, #T_249d9_row5_col2 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_249d9_row4_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_249d9_row4_col5 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_249d9_row4_col7, #T_249d9_row6_col4, #T_249d9_row7_col6, #T_249d9_row8_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_249d9_row4_col9 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_249d9_row4_col10 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_249d9_row5_col4 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_249d9_row5_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_249d9_row5_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_249d9_row5_col9 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_249d9_row5_col10 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_249d9_row6_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_249d9_row6_col3, #T_249d9_row7_col2, #T_249d9_row8_col2, #T_249d9_row9_col0, #T_249d9_row10_col0, #T_249d9_row10_col2, #T_249d9_row10_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_249d9_row6_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_249d9_row6_col7 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_249d9_row6_col8 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_249d9_row6_col9 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_249d9_row6_col10 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_249d9_row7_col0, #T_249d9_row8_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_249d9_row7_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_249d9_row7_col5, #T_249d9_row9_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_249d9_row7_col9, #T_249d9_row8_col9 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_249d9_row7_col10, #T_249d9_row8_col10 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_249d9_row8_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_249d9_row9_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_249d9_row9_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_249d9_row9_col5, #T_249d9_row10_col7, #T_249d9_row10_col8 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_249d9_row9_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_249d9_row10_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_249d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_249d9_level0_col0" class="col_heading level0 col0" >blister</th>
#       <th id="T_249d9_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_249d9_level0_col2" class="col_heading level0 col2" >shell_color</th>
#       <th id="T_249d9_level0_col3" class="col_heading level0 col3" >time_description</th>
#       <th id="T_249d9_level0_col4" class="col_heading level0 col4" >iso_press_avg</th>
#       <th id="T_249d9_level0_col5" class="col_heading level0 col5" >poly_press_avg</th>
#       <th id="T_249d9_level0_col6" class="col_heading level0 col6" >booth</th>
#       <th id="T_249d9_level0_col7" class="col_heading level0 col7" >iso_lbs_run_usage</th>
#       <th id="T_249d9_level0_col8" class="col_heading level0 col8" >poly_lbs_run_usage</th>
#       <th id="T_249d9_level0_col9" class="col_heading level0 col9" >Avg Temp</th>
#       <th id="T_249d9_level0_col10" class="col_heading level0 col10" >Avg Humidity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_249d9_level0_row0" class="row_heading level0 row0" >blister</th>
#       <td id="T_249d9_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_249d9_row0_col1" class="data row0 col1" >0.032208</td>
#       <td id="T_249d9_row0_col2" class="data row0 col2" >0.040647</td>
#       <td id="T_249d9_row0_col3" class="data row0 col3" >-0.010672</td>
#       <td id="T_249d9_row0_col4" class="data row0 col4" >-0.014878</td>
#       <td id="T_249d9_row0_col5" class="data row0 col5" >-0.025377</td>
#       <td id="T_249d9_row0_col6" class="data row0 col6" >0.006648</td>
#       <td id="T_249d9_row0_col7" class="data row0 col7" >0.043235</td>
#       <td id="T_249d9_row0_col8" class="data row0 col8" >0.044318</td>
#       <td id="T_249d9_row0_col9" class="data row0 col9" >-0.003374</td>
#       <td id="T_249d9_row0_col10" class="data row0 col10" >-0.001523</td>
#     </tr>
#     <tr>
#       <th id="T_249d9_level0_row1" class="row_heading level0 row1" >model</th>
#       <td id="T_249d9_row1_col0" class="data row1 col0" >0.032208</td>
#       <td id="T_249d9_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_249d9_row1_col2" class="data row1 col2" >0.104691</td>
#       <td id="T_249d9_row1_col3" class="data row1 col3" >0.029223</td>
#       <td id="T_249d9_row1_col4" class="data row1 col4" >0.003097</td>
#       <td id="T_249d9_row1_col5" class="data row1 col5" >0.002619</td>
#       <td id="T_249d9_row1_col6" class="data row1 col6" >0.100354</td>
#       <td id="T_249d9_row1_col7" class="data row1 col7" >-0.000276</td>
#       <td id="T_249d9_r

# %%
#Compute VIF data for each independent variable
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["features"] =X.columns
vif["vif_Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif
# Out:
#               features  vif_Factor
# 0              blister    1.013462
# 1                model    3.862330
# 2          shell_color    2.625129
# 3     time_description    2.870531
# 4        iso_press_avg  131.770818
# 5       poly_press_avg  117.720968
# 6                booth    6.410716
# 7    iso_lbs_run_usage  293.706623
# 8   poly_lbs_run_usage  295.336301
# 9             Avg Temp   14.745138
# 10        Avg Humidity    8.814319

# %%
X = df[['model','shell_color','time_description','poly_press_avg','booth','Avg Temp']]
